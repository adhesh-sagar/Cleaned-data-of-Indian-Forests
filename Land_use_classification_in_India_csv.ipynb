# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/Forest%20Cover%20in%20Indian%20States%20and%20Union%20Territories%20(2007-13).csv'

# %%
p='https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/Land%20use%20classification%20in%20India%20.csv'

# %% [markdown]
# First look of data

# %%
x= pd.read_csv(p)
x
# Out:
#                                            Unnamed: 0  ...  2014-15#
# 0                               I.  Geographical area  ...    328.73
# 1   II. Reporting area for land utilisation statis...  ...    307.82
# 2                                           1.Forests  ...     71.79
# 3                                                 NaN  ...    (23.3)
# 4             2.  Not available for cultivation (a+b)  ...     43.88
# 5                          (a)  Non-agricultural uses  ...     26.88
# 6                                                 NaN  ...     (8.7)
# 7                   (b)  Barren and uncultivable land  ...     17.00
# 8                                                 NaN  ...     (5.5)
# 9   3.  Other uncultivated land excluding fallow l...  ...     25.83
# 10      (a) Permanent pastures and other grazing land  ...     10.26
# 11                                                NaN  ...     (3.3)
# 12            (b) Miscellaneous tree crops and groves  ...      3.10
# ...

# %%
x.drop(columns=['Classification','1950-51','1960-61','1970-71','1980-81','1990-91','2000-01'], inplace=True)

# %%
x.head()
# Out:
#                                           Unnamed: 0 2010-11#  ... 2013-14# 2014-15#
# 0                              I.  Geographical area   328.73  ...   328.73   328.73
# 1  II. Reporting area for land utilisation statis...   307.48  ...   307.80   307.82
# 2                                          1.Forests    71.59  ...    71.83    71.79
# 3                                                NaN   (23.3)  ...   (23.3)   (23.3)
# 4            2.  Not available for cultivation (a+b)    43.58  ...    43.86    43.88
#
# [5 rows x 6 columns]

# %% [markdown]
# Renaming the column names

# %%
x.columns=['Classification','2010-11','2011-12','2012-13','2013-14','2014-15']

# %%
x
# Out:
#                                        Classification 2010-11  ... 2013-14 2014-15
# 0                               I.  Geographical area  328.73  ...  328.73  328.73
# 1   II. Reporting area for land utilisation statis...  307.48  ...  307.80  307.82
# 2                                           1.Forests   71.59  ...   71.83   71.79
# 3                                                 NaN  (23.3)  ...  (23.3)  (23.3)
# 4             2.  Not available for cultivation (a+b)   43.58  ...   43.86   43.88
# 5                          (a)  Non-agricultural uses   26.40  ...   26.91   26.88
# 6                                                 NaN   (8.6)  ...   (8.7)   (8.7)
# 7                   (b)  Barren and uncultivable land   17.18  ...   16.95   17.00
# 8                                                 NaN   (5.6)  ...   (5.5)   (5.5)
# 9   3.  Other uncultivated land excluding fallow l...   26.15  ...   25.83   25.83
# ...

# %% [markdown]
# removing unrequired rows

# %%
x=x.dropna()

# %%
x
# Out:
#                                        Classification 2010-11  ... 2013-14 2014-15
# 0                               I.  Geographical area  328.73  ...  328.73  328.73
# 1   II. Reporting area for land utilisation statis...  307.48  ...  307.80  307.82
# 2                                           1.Forests   71.59  ...   71.83   71.79
# 4             2.  Not available for cultivation (a+b)   43.58  ...   43.86   43.88
# 5                          (a)  Non-agricultural uses   26.40  ...   26.91   26.88
# 7                   (b)  Barren and uncultivable land   17.18  ...   16.95   17.00
# 9   3.  Other uncultivated land excluding fallow l...   26.15  ...   25.83   25.83
# 10      (a) Permanent pastures and other grazing land   10.31  ...   10.26   10.26
# 12            (b) Miscellaneous tree crops and groves    3.20  ...    3.19    3.10
# 14                          (c) Culturable waste land   12.65  ...   12.39   12.47
# ...

# %% [markdown]
# index reset

# %%
x.reset_index(drop=True, inplace = True)

# %%
x
# Out:
#                                        Classification 2010-11  ... 2013-14 2014-15
# 0                               I.  Geographical area  328.73  ...  328.73  328.73
# 1   II. Reporting area for land utilisation statis...  307.48  ...  307.80  307.82
# 2                                           1.Forests   71.59  ...   71.83   71.79
# 3             2.  Not available for cultivation (a+b)   43.58  ...   43.86   43.88
# 4                          (a)  Non-agricultural uses   26.40  ...   26.91   26.88
# 5                   (b)  Barren and uncultivable land   17.18  ...   16.95   17.00
# 6   3.  Other uncultivated land excluding fallow l...   26.15  ...   25.83   25.83
# 7       (a) Permanent pastures and other grazing land   10.31  ...   10.26   10.26
# 8             (b) Miscellaneous tree crops and groves    3.20  ...    3.19    3.10
# 9                           (c) Culturable waste land   12.65  ...   12.39   12.47
# ...

# %%
x.dtypes
# Out:
# Classification     object
# 2010-11           float64
# 2011-12            object
# 2012-13            object
# 2013-14            object
# 2014-15            object
# dtype: object

# %%
x['2010-11']=x['2010-11'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x['2011-12']=x['2011-12'].astype(float)
x['2012-13']=x['2012-13'].astype(float)
x['2013-14']=x['2013-14'].astype(float)
x['2014-15']=x['2014-15'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x.dtypes
# Out:
# Classification     object
# 2010-11           float64
# 2011-12           float64
# 2012-13           float64
# 2013-14           float64
# 2014-15           float64
# dtype: object

# %% [markdown]
# Conver to csv

# %%
x.to_csv('Land use classification in India.csv')
