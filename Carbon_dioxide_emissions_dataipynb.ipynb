# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/CO2%20_Emission_Statewise.xlsx.csv'

# %%
c_1= pd.read_csv(url)

# %%
c_1.columns=['Administrative area	','Total area (ha)','Tree cover Extent in 2000 (ha)','Tree cover Extent in 2010 (ha)','Carbon biomass (Mt)','Carbon emissions 2001-18 (Mt)','Avg carbon emissions/year 2001-18 (Mt)','Avg carbon emissions/year	2001-10 (Mt)','Avg carbon emissions/year 2011-18 (Mt)']

# %%
c_1
# Out:
#    Carbon dioxide emissions data for subnational administrative areas in India  ...      Unnamed: 8
# 0                                                 NaN                           ...             NaN
# 1                                 Administrative area                           ...      Avg carbon
# 2                                                 NaN                           ...  emissions/year
# 3                                                 NaN                           ...    2011-18 (Mt)
# 4                                 Andaman and Nicobar                           ...          172870
# 5                                      Andhra Pradesh                           ...          678810
# 6                                   Arunachal Pradesh                           ...         5645442
# 7                                               Assam                           ...         5752701
# ...

# %%
c_1.columns=['Administrative area	','Total area (ha)','Tree cover Extent in 2000 (ha)','Tree cover Extent in 2010 (ha)','Carbon biomass (Mt)','Carbon emissions 2001-18 (Mt)','Avg carbon emissions/year 2001-18 (Mt)','Avg carbon emissions/year	2001-10 (Mt)','Avg carbon emissions/year 2011-18 (Mt)']

# %%
c_1.head()
# Out:
#   Administrative area\t  ... Avg carbon emissions/year 2011-18 (Mt)
# 0                   NaN  ...                                    NaN
# 1   Administrative area  ...                             Avg carbon
# 2                   NaN  ...                         emissions/year
# 3                   NaN  ...                           2011-18 (Mt)
# 4   Andaman and Nicobar  ...                                 172870
#
# [5 rows x 9 columns]

# %%
c_1.drop(labels=[0,1,2,3],axis=0, inplace=True)

# %%
c_1
# Out:
#      Administrative area\t  ... Avg carbon emissions/year 2011-18 (Mt)
# 4      Andaman and Nicobar  ...                                 172870
# 5           Andhra Pradesh  ...                                 678810
# 6        Arunachal Pradesh  ...                                5645442
# 7                    Assam  ...                                5752701
# 8                    Bihar  ...                                  11682
# 9               Chandigarh  ...                                     21
# 10            Chhattisgarh  ...                                 953911
# 11  Dadra and Nagar Haveli  ...                                      0
# 12           Daman and Diu  ...                                      3
# 13                     Goa  ...                                  17943
# 14                 Gujarat  ...                                   1544
# 15                 Haryana  ...                                   2731
# ...

# %%
c_1.reset_index(drop=True, inplace=True)

# %%
c_1.head()
# Out:
#   Administrative area\t  ... Avg carbon emissions/year 2011-18 (Mt)
# 0   Andaman and Nicobar  ...                                 172870
# 1        Andhra Pradesh  ...                                 678810
# 2     Arunachal Pradesh  ...                                5645442
# 3                 Assam  ...                                5752701
# 4                 Bihar  ...                                  11682
#
# [5 rows x 7 columns]

# %%
c_1.drop(columns='Tree cover Extent in 2000 (ha)',axis=1,inplace=True)

# %%
c_1.drop(columns='Avg carbon emissions/year\t2001-10 (Mt)',axis=1,inplace=True)

# %%
c_1.head()
# Out:
#   Administrative area\t  ... Avg carbon emissions/year 2011-18 (Mt)
# 0   Andaman and Nicobar  ...                                 172870
# 1        Andhra Pradesh  ...                                 678810
# 2     Arunachal Pradesh  ...                                5645442
# 3                 Assam  ...                                5752701
# 4                 Bihar  ...                                  11682
#
# [5 rows x 8 columns]

# %%
c_1.dtypes
# Out:
# Administrative area\t                     object
# Total area (ha)                            int64
# Tree cover Extent in 2010 (ha)            object
# Carbon biomass (Mt)                       object
# Carbon emissions 2001-18 (Mt)             object
# Avg carbon emissions/year 2001-18 (Mt)    object
# Avg carbon emissions/year 2011-18 (Mt)    object
# dtype: object

# %%
type(c_1['Avg carbon emissions/year 2001-18 (Mt)'][8])
# Out:
# str

# %%
c_1.head()
# Out:
#   Administrative area\t  ... Avg carbon emissions/year 2011-18 (Mt)
# 0   Andaman and Nicobar  ...                                 172870
# 1        Andhra Pradesh  ...                                 678810
# 2     Arunachal Pradesh  ...                                5645442
# 3                 Assam  ...                                5752701
# 4                 Bihar  ...                                  11682
#
# [5 rows x 7 columns]

# %%
c_1['Total area (ha)']=c_1['Total area (ha)'].astype(int)

# %%
c_1['Tree cover Extent in 2010 (ha)']=c_1['Tree cover Extent in 2010 (ha)'].astype(int)
c_1['Carbon biomass (Mt)']=c_1['Carbon emissions 2001-18 (Mt)'].astype(int)
c_1['Carbon emissions 2001-18 (Mt)']=c_1['Carbon emissions 2001-18 (Mt)'].astype(int)
c_1['Avg carbon emissions/year 2001-18 (Mt)']=c_1['Avg carbon emissions/year 2001-18 (Mt)'].astype(int)
c_1['Avg carbon emissions/year 2011-18 (Mt)']=c_1['Avg carbon emissions/year 2011-18 (Mt)'].astype(int)

# %%
c_1.dtypes
# Out:
# Administrative area\t                     object
# Total area (ha)                            int64
# Tree cover Extent in 2010 (ha)             int64
# Carbon biomass (Mt)                        int64
# Carbon emissions 2001-18 (Mt)              int64
# Avg carbon emissions/year 2001-18 (Mt)     int64
# Avg carbon emissions/year 2011-18 (Mt)     int64
# dtype: object

# %% [markdown]
# Data of Carbon dioxide emissions  for subnational administrative areas in India

# %%
c_1.style.set_caption("Carbon dioxide emissions data for subnational administrative areas in India")
# Out:
# <style  type="text/css" >
# </style><table id="T_64f9c39c_1188_11ec_8dc8_0242ac1c0002" ><caption>Carbon dioxide emissions data for subnational administrative areas in India</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Administrative area	</th>        <th class="col_heading level0 col1" >Total area (ha)</th>        <th class="col_heading level0 col2" >Tree cover Extent in 2010 (ha)</th>        <th class="col_heading level0 col3" >Carbon biomass (Mt)</th>        <th class="col_heading level0 col4" >Carbon emissions 2001-18 (Mt)</th>        <th class="col_heading level0 col5" >Avg carbon emissions/year 2001-18 (Mt)</th>        <th class="col_heading level0 col6" >Avg carbon emissions/year 2011-18 (Mt)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64f9c39c_1188_11ec_8dc8_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
c_1.to_csv('Carbon dioxide emissions data for subnational administrative areas in India')
