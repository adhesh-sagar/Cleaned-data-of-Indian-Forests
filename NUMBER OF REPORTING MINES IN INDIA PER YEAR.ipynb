# %% [markdown]
# <a href="https://colab.research.google.com/github/Bruteforce004/Cleaned-data-of-Indian-Forests/blob/main/NUMBER%20OF%20REPORTING%20MINES%20IN%20INDIA%20PER%20YEAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url_1='https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/Total%20No.%20of%20mines%20all%20india.csv'

# %%
df = pd.read_csv(url_1)

# %% [markdown]
# First look of data

# %%
df
# Out:
#                                          Unnamed: 0  ... Unnamed: 20
# 0                                            MINING  ...         NaN
# 1   Table 15.1 - NUMBER OF REPORTING MINES IN INDIA  ...         NaN
# 2                                               NaN  ...         NaN
# 3                                              Year  ...         NaN
# 4                                               NaN  ...       Total
# 5                                               NaN  ...         NaN
# 6                                                 1  ...          21
# 7                                               NaN  ...         NaN
# 8                                           2000-01  ...        2030
# 9                                           2001-02  ...        2049
# 10                                          2002-03  ...        1992
# 11                                          2003-04  ...        1958
# 12                                         2004-05   ...        2013
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df.columns=['NUMBER OF REPORTING MINES IN INDIA PER YEAR','All Minerals Total(in numbers)','Fuel Coal','Fuel Lignite','Total Fuel','Metallic Minerals	Bauxite','Metallic Minerals Chromite','Metallic Minerals Iron ore','Metallic Minerals Manganese','Metallic Minerals others','Total Metallic Minerals','Non Metallic Menerals Dolomite','Non Metallic Menerals Felspar','Non Metallic Menerals Fire clay','Non Metallic Menerals Gypsum','Non_Metallic Menerals Kaolin','Non_Metallic Menerals Kaolin','Non Metallic Menerals Mica','Non Metallic Menerals steatite','Non Metallic Menerals other','NonMetallic Menerals Total']

# %%
df
# Out:
#    NUMBER OF REPORTING MINES IN INDIA PER YEAR  ... NonMetallic Menerals Total
# 0                                      2000-01  ...                       2030
# 1                                      2001-02  ...                       2049
# 2                                      2002-03  ...                       1992
# 3                                      2003-04  ...                       1958
# 4                                     2004-05   ...                       2013
# 5                                      2005-06  ...                       1807
# 6                                      2006-07  ...                       1796
# 7                                      2007-08  ...                       1762
# 8                                     2008-09   ...                       1782
# 9                                     2009-10   ...                       1781
# 10                                    2010-11   ...                       1826
# ...

# %%
df.drop(labels=[0,1,2,3,4,5,6,7], axis=0, inplace = True)

# %%
df.head()
# Out:
#    NUMBER OF REPORTING MINES IN INDIA PER YEAR  ... NonMetallic Menerals Total
# 8                                      2000-01  ...                       2030
# 9                                      2001-02  ...                       2049
# 10                                     2002-03  ...                       1992
# 11                                     2003-04  ...                       1958
# 12                                    2004-05   ...                       2013
#
# [5 rows x 21 columns]

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.head()
# Out:
#   NUMBER OF REPORTING MINES IN INDIA PER YEAR  ... NonMetallic Menerals Total
# 0                                     2000-01  ...                       2030
# 1                                     2001-02  ...                       2049
# 2                                     2002-03  ...                       1992
# 3                                     2003-04  ...                       1958
# 4                                    2004-05   ...                       2013
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# NUMBER OF REPORTING MINES IN INDIA PER YEAR    object
# All Minerals Total                             object
# Fuel Coal                                      object
# Fuel Lignite                                   object
# Total Fuel                                     object
# Metallic Minerals\tBauxite                     object
# Metallic Minerals Chromite                     object
# Metallic Minerals Iron ore                     object
# Metallic Minerals Manganese                    object
# Metallic Minerals others                       object
# Total Metallic Minerals                        object
# Non Metallic Menerals Dolomite                 object
# Non Metallic Menerals Felspar                  object
# Non Metallic Menerals Fire clay                object
# Non Metallic Menerals Gypsum                   object
# Non_Metallic Menerals Kaolin                   object
# Non_Metallic Menerals Kaolin                   object
# ...

# %%
p=df['NUMBER OF REPORTING MINES IN INDIA PER YEAR']

# %%
c=df.drop(columns='NUMBER OF REPORTING MINES IN INDIA PER YEAR')
c
# Out:
#    All Minerals Total(in numbers)  ... NonMetallic Menerals Total
# 0                            3191  ...                       2030
# 1                            3193  ...                       2049
# 2                            3145  ...                       1992
# 3                            3132  ...                       1958
# 4                            3209  ...                       2013
# 5                            2999  ...                       1807
# 6                            3005  ...                       1796
# 7                            3023  ...                       1762
# 8                            3075  ...                       1782
# 9                            3055  ...                       1781
# 10                           3118  ...                       1826
# 11                           3609  ...                       2354
# 12                           3978  ...                       2695
# ...

# %%
c=c.astype(int)

# %%
c.dtypes
# Out:
# All Minerals Total(in numbers)     int64
# Fuel Coal                          int64
# Fuel Lignite                       int64
# Total Fuel                         int64
# Metallic Minerals\tBauxite         int64
# Metallic Minerals Chromite         int64
# Metallic Minerals Iron ore         int64
# Metallic Minerals Manganese        int64
# Metallic Minerals others           int64
# Total Metallic Minerals            int64
# Non Metallic Menerals Dolomite     int64
# Non Metallic Menerals Felspar      int64
# Non Metallic Menerals Fire clay    int64
# Non Metallic Menerals Gypsum       int64
# Non_Metallic Menerals Kaolin       int64
# Non_Metallic Menerals Kaolin       int64
# Non Metallic Menerals Mica         int64
# Non Metallic Menerals steatite     int64
# Non Metallic Menerals other        int64
# NonMetallic Menerals Total         int64
# dtype: object

# %%
c['NUMBER OF REPORTING MINES IN INDIA PER YEAR']=p

# %%
c
# Out:
#     All Minerals Total(in numbers)  ...  NUMBER OF REPORTING MINES IN INDIA PER YEAR
# 0                             3191  ...                                      2000-01
# 1                             3193  ...                                      2001-02
# 2                             3145  ...                                      2002-03
# 3                             3132  ...                                      2003-04
# 4                             3209  ...                                     2004-05
# 5                             2999  ...                                      2005-06
# 6                             3005  ...                                      2006-07
# 7                             3023  ...                                      2007-08
# 8                             3075  ...                                     2008-09
# 9                             3055  ...                                     2009-10
# ...

# %%
c.to_csv('NUMBER OF REPORTING MINES IN INDIA PER YEAR.csv')
