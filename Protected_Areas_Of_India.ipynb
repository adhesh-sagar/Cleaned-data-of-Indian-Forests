# %% [markdown]
# ### **`Protected Areas Of India`**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Let's import the total forest cover of india-2013

# %%
url='https://raw.githubusercontent.com/sg-008/Data-of-Indian-Forests/main/Protected_Area_India.csv'
data_5=pd.read_csv(url)

# %% [markdown]
# First look of data

# %%
data_5.head()
# Out:
#   State/Union Territory  No. of national parks  ... No. of sanctuaries  Area (km2).1
# 0        Andhra Pradesh                      6  ...                 21     11,618.12
# 1     Arunachal Pradesh                      2  ...                 11      7,487.75
# 2                 Assam                      5  ...                 18      1,932.01
# 3                 Bihar                      1  ...                 12      2,851.67
# 4          Chhattisgarh                      3  ...                 11      3,583.19
#
# [5 rows x 5 columns]

# %% [markdown]
# Let's rename the columns

# %%
data_5.columns=['State/Union Territory','No.of national parks','Area of national parks (Km)','No. of sanctuaries','Area of sanctuaries (Km)']

# %%
data_5
# Out:
#    State/Union Territory  ...  Area of sanctuaries (Km)
# 0         Andhra Pradesh  ...                 11,618.12
# 1      Arunachal Pradesh  ...                  7,487.75
# 2                  Assam  ...                  1,932.01
# 3                  Bihar  ...                  2,851.67
# 4           Chhattisgarh  ...                  3,583.19
# 5                    Goa  ...                    647.91
# 6                Gujarat  ...                 16,619.81
# 7                Haryana  ...                    233.21
# 8       Himachal Pradesh  ...                   7745.48
# 9        Jammu & Kashmir  ...                 10,243.11
# 10             Jharkhand  ...                  1,955.82
# 11             Karnataka  ...                  4,003.42
# 12                Kerala  ...                  1,822.86
# 13        Madhya Pradesh  ...                  7,158.41
# 14           Maharashtra  ...                 14,152.70
# 15               Manipur  ...                    184.40
# ...

# %% [markdown]
# Let's check the data type of each column

# %%
data_5.dtypes
# Out:
# State/Union Territory          object
# No.of national parks            int64
# Area of national parks (Km)    object
# No. of sanctuaries              int64
# Area of sanctuaries (Km)       object
# dtype: object

# %%
data_5['Area of national parks (Km)']=data_5['Area of national parks (Km)'].str.replace(',','')
data_5['Area of national parks (Km)']=data_5['Area of national parks (Km)'].astype(float)
data_5['Area of sanctuaries (Km)']=data_5['Area of sanctuaries (Km)'].str.replace(',','')
data_5['Area of sanctuaries (Km)']=data_5['Area of sanctuaries (Km)'].astype(float)

# %%
data_5.dtypes
# Out:
# State/Union Territory           object
# No.of national parks             int64
# Area of national parks (Km)    float64
# No. of sanctuaries               int64
# Area of sanctuaries (Km)       float64
# dtype: object

# %% [markdown]
# Converting the Dataframe back to the csv file

# %%
data_4.to_csv('Protected_Areas_Of_India.csv')

# %% [markdown]
#  total forest cover of india-2019 data after performing data clean operation

# %%
data_5.style.set_caption("Protected Areas Of India")
# Out:
# <style  type="text/css" >
# </style><table id="T_477230d2_108b_11ec_abb3_0242ac1c0002" ><caption>Protected Areas Of India</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State/Union Territory</th>        <th class="col_heading level0 col1" >No.of national parks</th>        <th class="col_heading level0 col2" >Area of national parks (Km)</th>        <th class="col_heading level0 col3" >No. of sanctuaries</th>        <th class="col_heading level0 col4" >Area of sanctuaries (Km)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_477230d2_108b_11ec_abb3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_477230d2_108b_11ec_abb3_0242ac1c0002row0_col0" class="data row0 col0" >Andhra Pradesh</td>
#                         <td id="T_477230d2_108b_11ec_abb3_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
# ...
