# %% [markdown]
# ## **Statewise forest data-2013**

# %%
import pandas as pd

# %%
data_1=pd.read_excel('data_1.xlsx')

# %% [markdown]
# First look of data

# %%
data_1
# Out:
#               State/ Uts Geographical Area  ... Change percent   Scrub
# 0         Andhra Pradesh          2,75,069  ...          -0.10  10,465
# 1      Arunachal Pradesh            83,743  ...          -0.11     121
# 2                  Assam            78,438  ...           0.00     182
# 3                  Bihar            94,163  ...           0.47     115
# 4           Chhattisgarh          1,35,191  ...          -0.04     117
# 5                  Delhi             1,483  ...           0.24    2.24
# 6                    Goa             3,702  ...           0.00       0
# 7                Gujarat          1,96,022  ...           0.02   1,492
# 8                Haryana            44,212  ...          -0.05     150
# 9       Himachal Pradesh            55,673  ...           0.01     298
# 10    Jammu and Kashmir*          2,22,236  ...           0.00   2,105
# 11             Jharkhand            79,714  ...           0.62     670
# ...

# %%
data_1.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                         object
# 2013 Assessment - Very Dense Forest       object
# 2013 Assessment - Mod. Dense Forest       object
# 2013 Assessment - Open Forest Forest      object
# 2013 Assessment - Total Forest Forest     object
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# Scrub                                     object
# dtype: object

# %%
data_2=data_1.iloc[:,:]

# %%
data_2
# Out:
#               State/ Uts Geographical Area  ... Change percent   Scrub
# 0         Andhra Pradesh          2,75,069  ...          -0.10  10,465
# 1      Arunachal Pradesh            83,743  ...          -0.11     121
# 2                  Assam            78,438  ...           0.00     182
# 3                  Bihar            94,163  ...           0.47     115
# 4           Chhattisgarh          1,35,191  ...          -0.04     117
# 5                  Delhi             1,483  ...           0.24    2.24
# 6                    Goa             3,702  ...           0.00       0
# 7                Gujarat          1,96,022  ...           0.02   1,492
# 8                Haryana            44,212  ...          -0.05     150
# 9       Himachal Pradesh            55,673  ...           0.01     298
# 10    Jammu and Kashmir*          2,22,236  ...           0.00   2,105
# 11             Jharkhand            79,714  ...           0.62     670
# ...

# %%
data_2['Geographical Area']=data_2['Geographical Area'].str.replace(',','')
data_2['2013 Assessment - Very Dense Forest']=data_2['2013 Assessment - Very Dense Forest'].str.replace(',','')
data_2['2013 Assessment - Mod. Dense Forest']=data_2['2013 Assessment - Mod. Dense Forest'].str.replace(',', '')
data_2['2013 Assessment - Open Forest Forest']=data_2['2013 Assessment - Open Forest Forest'].str.replace(',','')
data_2['2013 Assessment - Total Forest Forest']=data_2['2013 Assessment - Total Forest Forest'].str.replace(',','')

# %% [markdown]
# This data has combination of int and string in columns

# %%
data_2
# Out:
#               State/ Uts Geographical Area  ... Change percent   Scrub
# 0         Andhra Pradesh            275069  ...          -0.10  10,465
# 1      Arunachal Pradesh             83743  ...          -0.11     121
# 2                  Assam             78438  ...           0.00     182
# 3                  Bihar             94163  ...           0.47     115
# 4           Chhattisgarh            135191  ...          -0.04     117
# 5                  Delhi              1483  ...           0.24    2.24
# 6                    Goa              3702  ...           0.00       0
# 7                Gujarat            196022  ...           0.02   1,492
# 8                Haryana             44212  ...          -0.05     150
# 9       Himachal Pradesh             55673  ...           0.01     298
# 10    Jammu and Kashmir*            222236  ...           0.00   2,105
# 11             Jharkhand             79714  ...           0.62     670
# ...

# %%
data_4=data_1.iloc[30:35, :]

# %%
data_4
# Out:
#               State/ Uts Geographical Area  ... Change percent Scrub
# 30            Chandigarh               114  ...           0.23  0.56
# 31  Dadra & Nagar Haveli               491  ...           0.41     1
# 32           Daman & Diu                12  ...           2.92  0.96
# 33           Lakshadweep                32  ...           0.19     0
# 34            Puducherry               480  ...           0.01     0
#
# [5 rows x 10 columns]

# %%
data_4['2013 Assessment - Very Dense Forest']=data_4['2013 Assessment - Very Dense Forest'].astype(float)
data_4['2013 Assessment - Mod. Dense Forest']=data_4['2013 Assessment - Mod. Dense Forest'].astype(float)
data_4['2013 Assessment - Open Forest Forest']=data_4['2013 Assessment - Open Forest Forest'].astype(float)
data_4['2013 Assessment - Total Forest Forest']=data_4['2013 Assessment - Total Forest Forest'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_4['Geographical Area']=data_4['Geographical Area'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_4['Scrub']=data_4['Scrub'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_4.drop(columns='Scrub', axis =1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_4.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                          int64
# 2013 Assessment - Very Dense Forest      float64
# 2013 Assessment - Mod. Dense Forest      float64
# 2013 Assessment - Open Forest Forest     float64
# 2013 Assessment - Total Forest Forest    float64
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# dtype: object

# %%
data_4['Scrub']=data_4['Scrub'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
type(k)
# Out:
# pandas.core.series.Series

# %%
data_5=data_1.iloc[0:30,:]

# %%
data_5
# Out:
#             State/ Uts  Geographical Area  ...  Change percent    Scrub
# 0       Andhra Pradesh             275069  ...           -0.10  10465.0
# 1    Arunachal Pradesh              83743  ...           -0.11      NaN
# 2                Assam              78438  ...            0.00      NaN
# 3                Bihar              94163  ...            0.47      NaN
# 4         Chhattisgarh             135191  ...           -0.04      NaN
# 5                Delhi               1483  ...            0.24      NaN
# 6                  Goa               3702  ...            0.00      NaN
# 7              Gujarat             196022  ...            0.02   1492.0
# 8              Haryana              44212  ...           -0.05      NaN
# 9     Himachal Pradesh              55673  ...            0.01      NaN
# 10  Jammu and Kashmir*             222236  ...            0.00   2105.0
# 11           Jharkhand              79714  ...            0.62      NaN
# ...

# %%
data_5['Geographical Area']=data_5['Geographical Area'].str.replace(',','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5['Geographical Area']=data_5['Geographical Area'].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                          int64
# 2013 Assessment - Very Dense Forest      float64
# 2013 Assessment - Mod. Dense Forest      float64
# 2013 Assessment - Open Forest Forest     float64
# 2013 Assessment - Total Forest Forest    float64
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# dtype: object

# %%
data_5['2013 Assessment - Very Dense Forest']=[850,20828,1444,247,4153,6.76,543,376,27,3224,4140,2587,1777,1529,6632,8720,728,449,138,1298,7042,0,72,500,2948,109,1623,4785,2971,3754]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_1['2013 Assessment - Mod. Dense Forest'][21]
# Out:
# 736

# %%
data_5.at[5,'2013 Assessment - Mod. Dense Forest']='49.38'

# %%
data_5.at[6,'2013 Assessment - Mod. Dense Forest']='585'
data_5.at[8,'2013 Assessment - Mod. Dense Forest']='453'
data_5.at[21,'2013 Assessment - Mod. Dense Forest']='736'

# %%
data_5['2013 Assessment - Mod. Dense Forest']=data_5['2013 Assessment - Mod. Dense Forest'].str.replace(',','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5['2013 Assessment - Mod. Dense Forest']=data_5['2013 Assessment - Mod. Dense Forest'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_1['2013 Assessment - Open Forest Forest'][29]
# Out:
# 544

# %%
data_5.at[5,'2013 Assessment - Open Forest Forest']='123.67'
data_5.at[6,'2013 Assessment - Open Forest Forest']='1091'
data_5.at[23,'2013 Assessment - Open Forest Forest']='697'
data_5.at[29,'2013 Assessment - Open Forest Forest']='544'

# %%
data_5['2013 Assessment - Open Forest Forest']=data_5['2013 Assessment - Open Forest Forest'].str.replace(',','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5['2013 Assessment - Open Forest Forest']=data_5['2013 Assessment - Open Forest Forest'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5['Scrub']=data_5['Scrub'].str.replace(',','').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_1['2013 Assessment - Total Forest Forest'][6]
# Out:
# 2219

# %%
data_5.at[5,'2013 Assessment - Total Forest Forest']='179.81'
data_5.at[6,'2013 Assessment - Total Forest Forest']='2219'

# %%
data_5['2013 Assessment - Total Forest Forest']=data_5['2013 Assessment - Total Forest Forest'].str.replace(',','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5['2013 Assessment - Total Forest Forest']=data_5['2013 Assessment - Total Forest Forest'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_5.drop(columns='Scrub',axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_4.to_csv('data_4.csv')
data_5.to_csv('data_5.csv')

# %%
o=pd.concat([data_5,data_4],ignore_index=True)

# %%
o
# Out:
#               State/ Uts  ...  Change percent
# 0         Andhra Pradesh  ...           -0.10
# 1      Arunachal Pradesh  ...           -0.11
# 2                  Assam  ...            0.00
# 3                  Bihar  ...            0.47
# 4           Chhattisgarh  ...           -0.04
# 5                  Delhi  ...            0.24
# 6                    Goa  ...            0.00
# 7                Gujarat  ...            0.02
# 8                Haryana  ...           -0.05
# 9       Himachal Pradesh  ...            0.01
# 10    Jammu and Kashmir*  ...            0.00
# 11             Jharkhand  ...            0.62
# 12             Karnataka  ...           -0.03
# 13                Kerala  ...            1.60
# 14       #Madhya Pradesh  ...           -0.06
# 15           Maharashtra  ...            0.00
# 16               Manipur  ...           -0.45
# 17             Meghalaya  ...            0.06
# 18               Mizoram  ...           -0.30
# ...

# %%
o.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                          int64
# 2013 Assessment - Very Dense Forest      float64
# 2013 Assessment - Mod. Dense Forest      float64
# 2013 Assessment - Open Forest Forest     float64
# 2013 Assessment - Total Forest Forest    float64
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# dtype: object

# %%
data_1['Scrub'][23]
# Out:
# 311

# %%
data_1.at[0,'Scrub']=10465
data_1.at[7,'Scrub']=1492
data_1.at[10,'Scrub']=2105
data_1.at[12,'Scrub']=3216
data_1.at[14,'Scrub']=6389
data_1.at[15,'Scrub']=4157
data_1.at[20,'Scrub']=4424
data_1.at[22,'Scrub']=4211
data_1.at[24,'Scrub']=1212

# %%
data_1.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                         object
# 2013 Assessment - Very Dense Forest       object
# 2013 Assessment - Mod. Dense Forest       object
# 2013 Assessment - Open Forest Forest      object
# 2013 Assessment - Total Forest Forest     object
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# Scrub                                     object
# dtype: object

# %%
data_1['Scrub']=data_1['Scrub'].str.replace(',','')

# %%
data_1['Scrub']=data_1['Scrub'].str.replace(',','')

# %%
data_1['Scrub']=[10465,121,182,115,117,2.24,0,1492,150,298,2105,670,3216,29,6389,4157,1,372,0,2,4424,37,4211,311,1212,66,806,262,111,57,0.56,1,0.96,0,0,41383]

# %%
data_1.dtypes
# Out:
# State/ Uts                                object
# Geographical Area                         object
# 2013 Assessment - Very Dense Forest       object
# 2013 Assessment - Mod. Dense Forest       object
# 2013 Assessment - Open Forest Forest      object
# 2013 Assessment - Total Forest Forest     object
# Percent of Geographical Area             float64
# Change in Forest Cover wrt ISFR 2011     float64
# Change percent                           float64
# Scrub                                    float64
# dtype: object

# %%
o['Scrub']=data_1['Scrub']

# %% [markdown]
# Final data

# %%
o
# Out:
#               State/ Uts  Geographical Area  ...  Change percent     Scrub
# 0         Andhra Pradesh             275069  ...           -0.10  10465.00
# 1      Arunachal Pradesh              83743  ...           -0.11    121.00
# 2                  Assam              78438  ...            0.00    182.00
# 3                  Bihar              94163  ...            0.47    115.00
# 4           Chhattisgarh             135191  ...           -0.04    117.00
# 5                  Delhi               1483  ...            0.24      2.24
# 6                    Goa               3702  ...            0.00      0.00
# 7                Gujarat             196022  ...            0.02   1492.00
# 8                Haryana              44212  ...           -0.05    150.00
# 9       Himachal Pradesh              55673  ...            0.01    298.00
# 10    Jammu and Kashmir*             222236  ...            0.00   2105.00
# ...

# %%
o.at[28,'State/ Uts']='West Bengal'
o.at[14,'State/ Uts']='Madhya Pradesh'
o.at[10,'State/ Uts']='Jammu and Kashmir'

# %%
o.head()
# Out:
#           State/ Uts  Geographical Area  ...  Change percent    Scrub
# 0     Andhra Pradesh             275069  ...           -0.10  10465.0
# 1  Arunachal Pradesh              83743  ...           -0.11    121.0
# 2              Assam              78438  ...            0.00    182.0
# 3              Bihar              94163  ...            0.47    115.0
# 4       Chhattisgarh             135191  ...           -0.04    117.0
#
# [5 rows x 10 columns]

# %% [markdown]
# Converting the DataFrame to csv

# %%
o.to_csv('Statewise Forest data of 2013.csv')
